# %%
import pandas as pd

# %%
chemical_df = pd.read_csv('chemicals.csv')
droughts_df = pd.read_csv('droughts.csv')

# %%
earnings_df = pd.read_csv('earnings.csv')
education_df = pd.read_csv('education_attainment.csv')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens (pandas\_libs\parsers.c:14858)()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype (pandas\_libs\parsers.c:17119)()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._string_convert (pandas\_libs\parsers.c:17347)()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers._string_box_utf8 (pandas\_libs\parsers.c:23041)()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xf1 in position 2: invalid continuation byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-3-59008c004b1a> in <module>()
# ----> 1 earnings_df = pd.read_csv('earnings.csv')
# ...

# %%
import plotly 
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

water_df = pd.read_csv("water_usage.csv")
industry_df = pd.read_csv("industry_occupation.csv", encoding = "latin1")
education_df = pd.read_csv("education_attainment.csv", encoding = "latin1")
earnings_df = pd.read_csv("earnings.csv", encoding = "latin1")
chemicals_df = pd.read_csv("chemicals.csv", encoding = "latin1")
droughts_df = pd.read_csv("droughts.csv", encoding = "latin1")

# %%
len(chemical_df)
# Out:
# 882319

# %%
chemical_df
# Out:
#                                       cws_name chemical_species  \
# 0         CALIFORNIA WATER SERVICE - LIVERMORE          Uranium
# 1                            CITY OF LIVERMORE          Uranium
# 2                           CITY OF PLEASANTON          Uranium
# 3           DUBLIN SAN RAMON SERVICES DISTRICT          Uranium
# 4           NORRIS CANYON PROPERTY OWNERS ASSN          Uranium
# 5                                   PARKS RFTA          Uranium
# 6               TRAILER HAVEN MOBILE HOME PARK          Uranium
# 7                          ZONE 7 WATER AGENCY          Uranium
# 8                ALAMEDA COUNTY WATER DISTRICT          Uranium
# 9                              CITY OF HAYWARD          Uranium
# 10          NORRIS CANYON PROPERTY OWNERS ASSN          Uranium
# 11               ALAMEDA COUNTY WATER DISTRICT          Uranium
# 12        CALIFORNIA WATER SERVICE - LIVERMORE          Uranium
# 13                             CITY OF HAYWARD          Uranium
# ...

# %%
chemical_df.describe()
# Out:
#          pop_served          value           year           fips  \
# count  8.823190e+05  882319.000000  882319.000000  882319.000000
# mean   1.073180e+04       7.434686    2008.854905   30189.924510
# std    9.520064e+04      23.677866       4.727939   15063.281913
# min    0.000000e+00       0.000000    1999.000000    6001.000000
# 25%    1.180000e+02       0.300000    2005.000000   19109.000000
# 50%    4.850000e+02       1.000000    2009.000000   33005.000000
# 75%    3.030000e+03       4.600000    2013.000000   42027.000000
# max    8.271000e+06    4527.000000    2016.000000   55141.000000
#
#           state_fips
# count  882319.000000
# mean       30.127847
# std        15.069085
# min         6.000000
# 25%        19.000000
# 50%        33.000000
# 75%        42.000000
# max        55.000000

# %%
chemical_df[chemical_df['year'] == 2000 ]
# Out:
#                                       cws_name chemical_species  \
# 0         CALIFORNIA WATER SERVICE - LIVERMORE          Uranium
# 1                            CITY OF LIVERMORE          Uranium
# 2                           CITY OF PLEASANTON          Uranium
# 3           DUBLIN SAN RAMON SERVICES DISTRICT          Uranium
# 4           NORRIS CANYON PROPERTY OWNERS ASSN          Uranium
# 5                                   PARKS RFTA          Uranium
# 6               TRAILER HAVEN MOBILE HOME PARK          Uranium
# 7                          ZONE 7 WATER AGENCY          Uranium
# 140                   ALMOND GROVE MOBILE PARK          Uranium
# 141                  BIG BEND MOBILE HOME PARK          Uranium
# 142        BUTTE CREEK ESTATES MUTUAL WATER CO          Uranium
# 143                CAL-WATER SERVICE CO.-CHICO          Uranium
# 144             CAL-WATER SERVICE CO.-OROVILLE          Uranium
# 145                  CHICO MOBILE COUNTRY CLUB          Uranium
# ...

# %%
education_df
# Out:
#         fips state                   county       year  less_than_hs  \
# 0          0    US            United States       1970    52373312.0
# 1       1000    AL                  Alabama       1970     1062306.0
# 2       1001    AL           Autauga County       1970        6611.0
# 3       1003    AL           Baldwin County       1970       18726.0
# 4       1005    AL           Barbour County       1970        8120.0
# 5       1007    AL              Bibb County       1970        5272.0
# 6       1009    AL            Blount County       1970       10677.0
# 7       1011    AL           Bullock County       1970        4245.0
# 8       1013    AL            Butler County       1970        8353.0
# 9       1015    AL           Calhoun County       1970       30535.0
# 10      1017    AL          Chambers County       1970       13616.0
# 11      1019    AL          Cherokee County       1970        6126.0
# 12      1021    AL           Chilton County       1970       10285.0
# ...

# %%
earnings_df
# Out:
#                geo_id   fips                        county  total_med  \
# 0      0500000US01001   1001       Autauga County, Alabama      31811
# 1      0500000US01003   1003       Baldwin County, Alabama      30099
# 2      0500000US01005   1005       Barbour County, Alabama      23504
# 3      0500000US01007   1007          Bibb County, Alabama      30453
# 4      0500000US01009   1009        Blount County, Alabama      30739
# 5      0500000US01011   1011       Bullock County, Alabama      23676
# 6      0500000US01013   1013        Butler County, Alabama      24174
# 7      0500000US01015   1015       Calhoun County, Alabama      28435
# 8      0500000US01017   1017      Chambers County, Alabama      25886
# 9      0500000US01019   1019      Cherokee County, Alabama      28430
# 10     0500000US01021   1021       Chilton County, Alabama      30331
# 11     0500000US01023   1023       Choctaw County, Alabama      27514
# ...

# %%
df_med_year = earnings_df[['total_med','year']]

# %%
df_med_year
# Out:
#        total_med  year
# 0          31811  2010
# 1          30099  2010
# 2          23504  2010
# 3          30453  2010
# 4          30739  2010
# 5          23676  2010
# 6          24174  2010
# 7          28435  2010
# 8          25886  2010
# 9          28430  2010
# 10         30331  2010
# 11         27514  2010
# 12         29542  2010
# 13         28897  2010
# 14         27966  2010
# 15         28288  2010
# 16         29155  2010
# 17         24041  2010
# 18         26932  2010
# 19         23883  2010
# 20         25017  2010
# 21         26802  2010
# 22         27112  2010
# 23         25593  2010
# 24         24709  2010
# 25         31638  2010
# 26         26298  2010
# 27         28293  2010
# 28         26118  2010
# 29         23484  2010
# ...          ...   ...
# 21968      30523  2016
# 21969      40970  2016
# 21970      44802  2016
# 21971      32583  2016
# 21972      30941  2016
# 21973      33066  2016
# 21974      32171  2016
# 21975      24188  2016
# ...

# %%
df_chemicals_corr = chemical_df[['value','year']]

# %%
ans = []
for i in range(1999,2017):
    temp = df_chemicals_corr[df_chemicals_corr['year'] == i]
    temp = temp['value']
    print(temp.values)
    break
    x = temp.values.sum()
    ans.append(x)
    
    
    
#temp = df_chemicals_corr[df_chemicals_corr['year'] == 2002]
# Out:
# [ 14.93  65.67   2.54 ...,   0.78  22.65  34.65]

# %%
temp = temp['value']

# %%
ans
# Out:
# [80392.869999999995,
#  104337.48000000001,
#  97594.509999999995,
#  235826.67999999999,
#  196744.17999999999,
#  421538.72999999998,
#  381497.15000000002,
#  407132.70000000007,
#  429506.51000000001,
#  380016.84999999998,
#  391607.91000000003,
#  432878.54000000004,
#  402707.53999999998,
#  452031.46999999997,
#  513901.86000000004,
#  600371.82000000007,
#  553092.1100000001,
#  478585.48000000004]

# %%
v_2000 = 104337.48000000001
v_2001 = 97594.509999999995
v_2002 = 235826.67999999999

# %%
plt.scatter(chemical_df['year'],chemical_df['value'])

# %%
plt.show()

# %%
n = np.array([1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016])
plt.bar(n,ans)
# Out:
# <Container object of 18 artists>

# %%
chemical_df['year'].values
# Out:
# array([2000, 2000, 2000, ..., 2016, 2016, 2016], dtype=int64)

# %%
plt.show()

# %%
water_df['year'].nunique()
# Out:
# 1

# %%
chemical_df[['chemical_species','value','county','state']]
# Out:
#        chemical_species  value   county       state
# 0               Uranium   1.54  Alameda  California
# 1               Uranium   1.64  Alameda  California
# 2               Uranium   1.64  Alameda  California
# 3               Uranium   1.64  Alameda  California
# 4               Uranium   4.51  Alameda  California
# 5               Uranium   1.64  Alameda  California
# 6               Uranium   2.70  Alameda  California
# 7               Uranium   1.64  Alameda  California
# 8               Uranium   0.64  Alameda  California
# 9               Uranium   0.64  Alameda  California
# 10              Uranium   2.81  Alameda  California
# 11              Uranium   1.00  Alameda  California
# 12              Uranium   3.59  Alameda  California
# 13              Uranium   1.16  Alameda  California
# 14              Uranium   3.71  Alameda  California
# 15              Uranium   3.71  Alameda  California
# 16              Uranium   3.71  Alameda  California
# ...

# %%
#Lets try to find out most contaminated state, followed by chemical species it's more contaminated by
#find out species with highest value of contamination
#do more analysis on infrastructure of state with highest polution

f=chemical_df['state'].unique()

# %%
c =chemical_df[['value','state']]

a = []
for s in f:
    temp = c[c['state'] == s]
    temp = temp['value']
    x = temp.values.sum()
    a.append((s,x))
print(a)
# Out:
# [('California', 215773.77999999997), ('Colorado', 274312.57000000001), ('Connecticut', 212543.89999999999), ('Florida', 727625.26000000001), ('Iowa', 294675.79999999999), ('Kansas', 384667.06), ('Kentucky', 249250.61000000002), ('Louisiana', 312543.54999999999), ('Maryland', 79384.660000000003), ('Massachusetts', 151384.46000000002), ('Minnesota', 163698.33000000002), ('Missouri', 357774.18000000005), ('New Hampshire', 82135.899999999994), ('New Jersey', 181404.28000000003), ('New Mexico', 129217.96000000001), ('New York', 567931.06000000006), ('North Carolina', 239441.22), ('Oregon', 195835.76000000001), ('Pennsylvania', 566334.08000000007), ('South Carolina', 132966.64999999999), ('Utah', 67886.550000000003), ('Vermont', 128967.70000000001), ('Washington', 281358.20000000001), ('West Virginia', 273835.62), ('Wisconsin', 100250.17999999999), ('Maine', 96574.679999999993), ('Michigan', 91990.389999999999)]

# %%
max(a[0][1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-78-628f58ab81f7> in <module>()
# ----> 1 max(a[0][1])
#
# TypeError: 'numpy.float64' object is not iterable

# %%
a[0][1]
# Out:
# 215773.77999999997

# %%
def takeSecond(elem):
    return elem[1]

# sort list with key
sortedList = sorted(a, key=takeSecond)

# %%
sortedList
# Out:
# [('Utah', 67886.550000000003),
#  ('Maryland', 79384.660000000003),
#  ('New Hampshire', 82135.899999999994),
#  ('Michigan', 91990.389999999999),
#  ('Maine', 96574.679999999993),
#  ('Wisconsin', 100250.17999999999),
#  ('Vermont', 128967.70000000001),
#  ('New Mexico', 129217.96000000001),
#  ('South Carolina', 132966.64999999999),
#  ('Massachusetts', 151384.46000000002),
#  ('Minnesota', 163698.33000000002),
#  ('New Jersey', 181404.28000000003),
#  ('Oregon', 195835.76000000001),
#  ('Connecticut', 212543.89999999999),
#  ('California', 215773.77999999997),
#  ('North Carolina', 239441.22),
#  ('Kentucky', 249250.61000000002),
#  ('West Virginia', 273835.62),
#  ('Colorado', 274312.57000000001),
#  ('Washington', 281358.20000000001),
#  ('Iowa', 294675.79999999999),
#  ('Louisiana', 312543.54999999999),
#  ('Missouri', 357774.18000000005),
#  ('Kansas', 384667.06),
#  ('Pennsylvania', 566334.08000000007),
#  ('New York', 567931.06000000006),
#  ('Florida', 727625.26000000001)]

# %%
temp = chemical_df[chemical_df['state']=='Florida']

# %%
temp = temp[['chemical_species','value']]

# %%
temp.head()
# Out:
#       chemical_species  value
# 16503          Uranium   1.04
# 16504          Uranium   0.63
# 16505          Uranium   0.52
# 16506          Uranium   0.45
# 16507          Uranium   0.52

# %%
ls = temp['chemical_species'].unique()

# %%
ans_ = []
for chem in ls:
    tem = temp[temp['chemical_species'] == chem]
    tem = tem['value']
    x = tem.values.sum()
    ans_.append((chem,x))
print(ans_)
# Out:
# [('Uranium', 1690.1600000000001), ('Arsenic', 13347.200000000001), ('DEHP', 4831.5200000000004), ('Nitrates', 15786.620000000001), ('Halo-Acetic Acid', 237002.32000000001), ('Trihalomethane', 454967.44000000006)]

# %%
ans_1 = []
for chem in ls:
    tem = chemical_df[chemical_df['chemical_species'] == chem]
    tem = tem['value']
    x = tem.values.sum()
    ans_1.append((chem,x))
print(ans_1)
# Out:
# [('Uranium', 203078.40999999997), ('Arsenic', 403516.53000000003), ('DEHP', 59666.239999999998), ('Nitrates', 370176.22000000003), ('Halo-Acetic Acid', 1912109.25), ('Trihalomethane', 3611217.7399999998)]

# %%
def takeSecond(elem):
    return elem[1]

# sort list with key
sortedList1 = sorted(ans_1, key=takeSecond)
print(sortedList1)
# Out:
# [('DEHP', 59666.239999999998), ('Uranium', 203078.40999999997), ('Nitrates', 370176.22000000003), ('Arsenic', 403516.53000000003), ('Halo-Acetic Acid', 1912109.25), ('Trihalomethane', 3611217.7399999998)]

# %%
#chemical_df['contaminant_level'].unique()
chemical_df_upt = chemical_df.replace('Greater than MCL',2)

# %%
chemical_df_upt['contaminant_level'].unique()
# Out:
# array(['Less than or equal MCL', 'Non Detect', 2], dtype=object)

# %%
chemical_df_upt =chemical_df.replace('Less than or equal MCL',1)
chemical_df_upt =chemical_df_upt.replace('Non Detect',0)
chemical_df_upt =chemical_df_upt.replace('Greater than MCL',2)

# %%
chemical_df_upt['contaminant_level'].unique()
# Out:
# array([1, 0, 2], dtype=int64)

# %%
ans_2 = []
for chem in ls:
    tem = chemical_df_upt[chemical_df_upt['chemical_species'] == chem]
    tem = tem['contaminant_level']
    x = tem.values.sum()
    ans_2.append((chem,x))
print(ans_2)
# Out:
# [('Uranium', 24478), ('Arsenic', 48785), ('DEHP', 5278), ('Nitrates', 212436), ('Halo-Acetic Acid', 104967), ('Trihalomethane', 135100)]

# %%
a1 = []
for s in f:
    temp = chemical_df_upt[chemical_df_upt['state'] == s]
    temp = temp['contaminant_level']
    x = temp.values.sum()
    a1.append((s,x))
print(a1)
# Out:
# [('California', 41943), ('Colorado', 23111), ('Connecticut', 13482), ('Florida', 48433), ('Iowa', 20039), ('Kansas', 23496), ('Kentucky', 10957), ('Louisiana', 13336), ('Maryland', 9401), ('Massachusetts', 12286), ('Minnesota', 21345), ('Missouri', 22616), ('New Hampshire', 9699), ('New Jersey', 18674), ('New Mexico', 15708), ('New York', 39128), ('North Carolina', 11142), ('Oregon', 15467), ('Pennsylvania', 49083), ('South Carolina', 8918), ('Utah', 11510), ('Vermont', 8429), ('Washington', 37943), ('West Virginia', 12929), ('Wisconsin', 19327), ('Maine', 8230), ('Michigan', 4412)]

# %%
sortedList2 = sorted(a1, key=takeSecond)
print(sortedList2)
# Out:
# [('Michigan', 4412), ('Maine', 8230), ('Vermont', 8429), ('South Carolina', 8918), ('Maryland', 9401), ('New Hampshire', 9699), ('Kentucky', 10957), ('North Carolina', 11142), ('Utah', 11510), ('Massachusetts', 12286), ('West Virginia', 12929), ('Louisiana', 13336), ('Connecticut', 13482), ('Oregon', 15467), ('New Mexico', 15708), ('New Jersey', 18674), ('Wisconsin', 19327), ('Iowa', 20039), ('Minnesota', 21345), ('Missouri', 22616), ('Colorado', 23111), ('Kansas', 23496), ('Washington', 37943), ('New York', 39128), ('California', 41943), ('Florida', 48433), ('Pennsylvania', 49083)]

# %%
industry_df['county'].unique()
# Out:
# array(['Baldwin County, Alabama', 'Calhoun County, Alabama',
#        'Cullman County, Alabama', 'DeKalb County, Alabama',
#        'Elmore County, Alabama', 'Etowah County, Alabama',
#        'Houston County, Alabama', 'Jefferson County, Alabama',
#        'Lauderdale County, Alabama', 'Lee County, Alabama',
#        'Limestone County, Alabama', 'Madison County, Alabama',
#        'Marshall County, Alabama', 'Mobile County, Alabama',
#        'Montgomery County, Alabama', 'Morgan County, Alabama',
#        'St. Clair County, Alabama', 'Shelby County, Alabama',
#        'Talladega County, Alabama', 'Tuscaloosa County, Alabama',
#        'Walker County, Alabama', 'Anchorage Municipality, Alaska',
#        'Fairbanks North Star Borough, Alaska',
#        'Matanuska-Susitna Borough, Alaska', 'Apache County, Arizona',
#        'Cochise County, Arizona', 'Coconino County, Arizona',
#        'Maricopa County, Arizona', 'Mohave County, Arizona',
# ...

# %%
florida_county = ['Alachua County, Florida', 'Bay County, Florida',
       'Brevard County, Florida', 'Broward County, Florida',
       'Charlotte County, Florida', 'Citrus County, Florida',
       'Clay County, Florida', 'Collier County, Florida',
       'Columbia County, Florida', 'Duval County, Florida',
       'Escambia County, Florida', 'Flagler County, Florida',
       'Hernando County, Florida', 'Highlands County, Florida',
       'Hillsborough County, Florida', 'Indian River County, Florida',
       'Lake County, Florida', 'Lee County, Florida',
       'Leon County, Florida', 'Manatee County, Florida',
       'Marion County, Florida', 'Martin County, Florida',
       'Miami-Dade County, Florida', 'Monroe County, Florida',
       'Nassau County, Florida', 'Okaloosa County, Florida',
       'Orange County, Florida', 'Osceola County, Florida',
       'Palm Beach County, Florida', 'Pasco County, Florida',
       'Pinellas County, Florida', 'Polk County, Florida',
       'Putnam County, Florida', 'St. Johns County, Florida',
       'St. Lucie County, Florida', 'Santa Rosa County, Florida',
       'Sarasota County, Florida', 'Seminole County, Florida', 'Sumter County, Florida', 'Volusia County, Florida']

# %%
industry_df.head()
# Out:
#            geo_id  fips                   county  total_employed  agriculture  \
# 0  0500000US01003  1003  Baldwin County, Alabama         77263.0       1302.0
# 1  0500000US01015  1015  Calhoun County, Alabama         42768.0        337.0
# 2  0500000US01043  1043  Cullman County, Alabama             NaN          NaN
# 3  0500000US01049  1049   DeKalb County, Alabama             NaN          NaN
# 4  0500000US01051  1051   Elmore County, Alabama             NaN          NaN
#
#    construction  manufacturing  wholesale_trade  retail_trade  \
# 0        6489.0         6134.0           2131.0        9525.0
# 1        1371.0         7868.0            750.0        5706.0
# 2           NaN            NaN              NaN           NaN
# 3           NaN            NaN              NaN           NaN
# 4           NaN            NaN              NaN           NaN
#
#    transport_utilities  information  finance_insurance_realestate  \
# ...

# %%
count = 0
for county in florida_county:
    t = industry_df[industry_df['county' == county]]
    count+=t['agriculture']
print(count)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\purvak\anaconda3\envs\py35\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2392             try:
# -> 2393                 return self._engine.get_loc(key)
#    2394             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5239)()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5085)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20405)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20359)()
#
# KeyError: False
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
for county in florida_county:
    x =industry_df[industry_df['county'] == county]
    print(x)
    break
# Out:
#               geo_id   fips                   county  total_employed  \
# 108   0500000US12001  12001  Alachua County, Florida        112538.0
# 915   0500000US12001  12001  Alachua County, Florida        113211.0
# 1726  0500000US12001  12001  Alachua County, Florida        113902.0
# 2540  0500000US12001  12001  Alachua County, Florida        114725.0
# 3357  0500000US12001  12001  Alachua County, Florida        115183.0
# 4175  0500000US12001  12001  Alachua County, Florida        121517.0
# 4994  0500000US12001  12001  Alachua County, Florida        119879.0
#
#       agriculture  construction  manufacturing  wholesale_trade  retail_trade  \
# 108         983.0        3705.0         3926.0           1780.0       12816.0
# 915         486.0        4720.0         5112.0           1921.0       11222.0
# 1726        757.0        4573.0         3793.0           3034.0       12628.0
# 2540        820.0        3858.0         4610.0           2051.0       14370.0
# ...

# %%
states =chemicals_df['state'].unique()
ans2 = []
c =chemicals_df[['value','state']]
d = {}
for s in states:
    temp = c[c['state'] == s]
    temp = temp['value']
    x = temp.values.sum()
    ans2.append((s,x))
    d[s]=x

def takeSecond(elem):
    return elem[1]

# sort list with key
sortedList = sorted(ans2, key=takeSecond, reverse=True)
#print(sortedList)

k = []
v =[]

for key,values in d.items():
    k.append(key)
    v.append(values)

# %%
ts = pd.Series(v, index=k)

ts = ts.cumsum()

ts.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-138-5fd389491e50> in <module>()
#       3 ts = ts.cumsum()
#       4
# ----> 5 ts.show()
#
# c:\users\purvak\anaconda3\envs\py35\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    2968             if name in self._info_axis:
#    2969                 return self[name]
# -> 2970             return object.__getattribute__(self, name)
#    2971
#    2972     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'show'

# %%
# %matplotlib inline

# %%
x = droughts_df[droughts_df['state']=='CA']
x
# Out:
#         fips          county state    none     d0     d1   d2   d3   d4  \
# 76912   6001  Alameda County    CA  100.00   0.00   0.00  0.0  0.0  0.0
# 76913   6001  Alameda County    CA  100.00   0.00   0.00  0.0  0.0  0.0
# 76914   6001  Alameda County    CA  100.00   0.00   0.00  0.0  0.0  0.0
# 76915   6001  Alameda County    CA  100.00   0.00   0.00  0.0  0.0  0.0
# 76916   6001  Alameda County    CA  100.00   0.00   0.00  0.0  0.0  0.0
# 76917   6001  Alameda County    CA  100.00   0.00   0.00  0.0  0.0  0.0
# 76918   6001  Alameda County    CA  100.00   0.00   0.00  0.0  0.0  0.0
# 76919   6001  Alameda County    CA  100.00   0.00   0.00  0.0  0.0  0.0
# 76920   6001  Alameda County    CA  100.00   0.00   0.00  0.0  0.0  0.0
# 76921   6001  Alameda County    CA  100.00   0.00   0.00  0.0  0.0  0.0
# 76922   6001  Alameda County    CA  100.00   0.00   0.00  0.0  0.0  0.0
# 76923   6001  Alameda County    CA  100.00   0.00   0.00  0.0  0.0  0.0
# ...

# %%
x = {'Uranium(micrograms/L)': 2, 'Arsenic(micrograms/L)': 1, 'DEHP(micrograms/L)': 1, 'Nitrates(milligrams/L)': 2, 'Halo-Acetic Acid(micrograms/L)': 1, 'Trihalomethane(micrograms/L)': 2}
y ={'Uranium(micrograms/L)': np.array([-0.00584229,  0.72542275,  0.08034749,  0.02117824, -0.03213056,
      -0.04028493]), 'Arsenic(micrograms/L)': np.array([ 0.0008375 , -0.02308488,  0.07815932,  0.04418895, -0.03681452,
       0.06958854]), 'DEHP(micrograms/L)': np.array([-0.02464186, -0.12505089, -0.09959427, -0.06536517,  0.02902133,
       0.08917486]), 'Nitrates(milligrams/L)': np.array([ 9.02643105e-04,  1.15423081e+00,  9.82211576e-02,  2.61018523e-02,
      -6.28437209e-02, -5.42133463e-02]), 'Halo-Acetic Acid(micrograms/L)': np.array([ 0.00754173, -0.39016013,  0.08838049, -0.03296108, -0.07166619,
       0.03815253]), 'Trihalomethane(micrograms/L)': np.array([ 0.00165637,  1.0730999 ,  0.10397881,  0.02175341, -0.06810205,
      -0.04833789])}

# %%
x = ['Uranium(micrograms/L)','Arsenic(micrograms/L)','DEHP(micrograms/L)','Nitrates(milligrams/L)','Halo-Acetic Acid(micrograms/L)','Halo-Acetic Acid(micrograms/L)']
sns.stripplot(x ='chemicals',y='cluster points',data = y )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-150-99f50c519be7> in <module>()
#       1 x = ['Uranium(micrograms/L)','Arsenic(micrograms/L)','DEHP(micrograms/L)','Nitrates(milligrams/L)','Halo-Acetic Acid(micrograms/L)','Halo-Acetic Acid(micrograms/L)']
# ----> 2 sns.stripplot(x ='chemicals',y='cluster points',data = y )
#       3
#
# c:\users\purvak\anaconda3\envs\py35\lib\site-packages\seaborn\categorical.py in stripplot(x, y, hue, data, order, hue_order, jitter, split, orient, color, palette, size, edgecolor, linewidth, ax, **kwargs)
#    2545
#    2546     plotter = _StripPlotter(x, y, hue, data, order, hue_order,
# -> 2547                             jitter, split, orient, color, palette)
#    2548     if ax is None:
#    2549         ax = plt.gca()
#
# ...

# %%
sns.set(style="ticks", color_codes=True)

# %%
import seaborn as sns
sns.set(style="whitegrid")
tips = sns.load_dataset("tips")
ax = sns.stripplot(x=tips["total_bill"])

# %%
t=sns.load_dataset('tips')
t.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df = pd.DataFrame(y)

# %%
df
# Out:
#    Arsenic(micrograms/L)  DEHP(micrograms/L)  Halo-Acetic Acid(micrograms/L)  \
# 0               0.000838           -0.024642                        0.007542
# 1              -0.023085           -0.125051                       -0.390160
# 2               0.078159           -0.099594                        0.088380
# 3               0.044189           -0.065365                       -0.032961
# 4              -0.036815            0.029021                       -0.071666
# 5               0.069589            0.089175                        0.038153
#
#    Nitrates(milligrams/L)  Trihalomethane(micrograms/L)  Uranium(micrograms/L)
# 0                0.000903                      0.001656              -0.005842
# 1                1.154231                      1.073100               0.725423
# 2                0.098221                      0.103979               0.080347
# 3                0.026102                      0.021753               0.021178
# ...

# %%
sns.stripplot(x=df[['Arsenic(micrograms/L)'])

# %%
x = ['Uranium(micrograms/L)', 'Arsenic(micrograms/L)', 'DEHP(micrograms/L)', 'Nitrates(milligrams/L)', 'Halo-Acetic Acid(micrograms/L)', 'Trihalomethane(micrograms/L)']

# %%
d = {'chemical':['Uranium(micrograms/L)', 'Arsenic(micrograms/L)', 'DEHP(micrograms/L)', 'Nitrates(milligrams/L)', 'Halo-Acetic Acid(micrograms/L)', 'Trihalomethane(micrograms/L)'],
'value':[np.array([-0.00584229,  0.72542275,  0.08034749,  0.02117824, -0.03213056,
      -0.04028493]),np.array([-0.00584229,  0.72542275,  0.08034749,  0.02117824, -0.03213056,
      -0.04028493]),np.array([-0.00584229,  0.72542275,  0.08034749,  0.02117824, -0.03213056,
      -0.04028493]),np.array([-0.00584229,  0.72542275,  0.08034749,  0.02117824, -0.03213056,
      -0.04028493]),np.array([-0.00584229,  0.72542275,  0.08034749,  0.02117824, -0.03213056,
      -0.04028493]),np.array([-0.00584229,  0.72542275,  0.08034749,  0.02117824, -0.03213056,
      -0.04028493])]
    }

# %%
df = pd.DataFrame(d)

# %%
df
# Out:
#                  chemical     value
# 0   Uranium(micrograms/L) -0.005842
# 1   Uranium(micrograms/L)  0.725423
# 2   Uranium(micrograms/L)  0.080347
# 3   Uranium(micrograms/L)  0.021178
# 4   Uranium(micrograms/L) -0.032131
# 5   Uranium(micrograms/L) -0.040285
# 6   Arsenic(micrograms/L) -0.005842
# 7   Arsenic(micrograms/L)  0.725423
# 8   Arsenic(micrograms/L)  0.080347
# 9   Arsenic(micrograms/L)  0.021178
# 10  Arsenic(micrograms/L) -0.032131
# 11  Arsenic(micrograms/L) -0.040285

# %%
sns.stripplot(x="chemical", y="coefficients", data=df, jitter=True)

# %%
d = {'chemical':['Uranium', 'Uranium','Uranium','Uranium', 'Uranium','Uranium','Arsenic','Arsenic','Arsenic','Arsenic','Arsenic',
                 'Arsenic','DEHP','DEHP','DEHP','DEHP',
                'DEHP','DEHP','Nitrates','Nitrates','Nitrates',
                'Nitrates','Nitrates','Nitrates','Halo-Acetic Acid','Halo-Acetic Acid',
                 'Halo-Acetic Acid','Halo-Acetic Acid','Halo-Acetic Acid','Halo-Acetic Acid',
                 'Trihalomethane','Trihalomethane','Trihalomethane','Trihalomethane',
                'Trihalomethane','Trihalomethane'],
     'coefficients':[-0.00584229,  0.72542275,  0.08034749,  0.02117824, -0.03213056,
      -0.04028493,-0.00584229,  0.72542275,  0.08034749,  0.02117824, -0.03213056,
      -0.04028493,-0.00584229,  0.72542275,  0.08034749,  0.02117824, -0.03213056,
      -0.04028493,-0.00584229,  0.72542275,  0.08034749,  0.02117824, -0.03213056,
      -0.04028493,-0.00584229,  0.72542275,  0.08034749,  0.02117824, -0.03213056,
      -0.04028493,-0.00584229,  0.72542275,  0.08034749,  0.02117824, -0.03213056,
      -0.04028493]}

# %%
import seaborn as sns
sns.set(style="whitegrid")
tips = sns.load_dataset("tips")
#ax = sns.stripplot(x=tips["total_bill"])
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
x = [-0.00584229,  0.72542275,  0.08034749,  0.02117824, -0.03213056,
      -0.04028493,-0.00584229,  0.72542275,  0.08034749,  0.02117824, -0.03213056,
      -0.04028493,-0.00584229,  0.72542275,  0.08034749,  0.02117824, -0.03213056,
      -0.04028493,-0.00584229,  0.72542275,  0.08034749,  0.02117824, -0.03213056,
      -0.04028493,-0.00584229,  0.72542275,  0.08034749,  0.02117824, -0.03213056,
      -0.04028493,-0.00584229,  0.72542275,  0.08034749,  0.02117824, -0.03213056,
      -0.04028493]

# %%
len(x)
# Out:
# 36

# %%
y = ['Uranium(micrograms/L)', 'Uranium(micrograms/L)','Uranium(micrograms/L)','Uranium(micrograms/L)', 'Uranium(micrograms/L)','Uranium(micrograms/L)','Arsenic(micrograms/L)','Arsenic(micrograms/L)','Arsenic(micrograms/L)','Arsenic(micrograms/L)','Arsenic(micrograms/L)',
                 'Arsenic(micrograms/L)''DEHP(micrograms/L)','DEHP(micrograms/L)','DEHP(micrograms/L)','DEHP(micrograms/L)',
                'DEHP(micrograms/L)','DEHP(micrograms/L)','Nitrates(milligrams/L)','Nitrates(milligrams/L)','Nitrates(milligrams/L)',
                'Nitrates(milligrams/L)','Nitrates(milligrams/L)','Nitrates(milligrams/L)','Halo-Acetic Acid(micrograms/L)','Halo-Acetic Acid(micrograms/L)',
                 'Halo-Acetic Acid(micrograms/L)','Halo-Acetic Acid(micrograms/L)','Halo-Acetic Acid(micrograms/L)','Halo-Acetic Acid(micrograms/L)',
                 'Trihalomethane(micrograms/L)','Trihalomethane(micrograms/L)','Trihalomethane(micrograms/L)','Trihalomethane(micrograms/L)',
                'Trihalomethane(micrograms/L)','Trihalomethane(micrograms/L)']

# %%
Uranium(micrograms/L) [1.283533  0.6655166]
Arsenic(micrograms/L) [0.5992834  0.05447632]
DEHP(micrograms/L) [0.8421468  0.47115004]
Nitrates(milligrams/L) [0.79370046 0.9509962 ]
Halo-Acetic Acid(micrograms/L) [1.1633891 0.1114312]
Trihalomethane(micrograms/L) [0.3708179  0.57337654]
# Out:
# 35

# %%
x = [1.283533  ,0.5992834, 0.8421468 ,0.79370046 ,1.1633891 ,  0.57337654]
y = [0.6655166, 0.05447632]
